# %% [markdown]
# # Convolutional Neural Network

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Importing the libraries

# %%
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Generating images for the Training set

# %%
#All the code about image preprocessing can be found on keras documentation
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

# %% [markdown]
# ### Generating images for the Test set

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

# %% [markdown]
# ### Creating the Training set

# %%
training_set = train_datagen.flow_from_directory('/content/drive/My Drive/Colab Notebooks/ML/Deep Learning/Convolution Neural Network/dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# ### Creating the Test set

# %%
test_set = test_datagen.flow_from_directory('/content/drive/My Drive/Colab Notebooks/ML/Deep Learning/Convolution Neural Network/dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# ## Part 2 - Building the CNN

# %% [markdown]
# ### Importing the keras libraries and packages

# %%
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense

# %% [markdown]
# ### Initialising the CNN

# %%
classifier = Sequential()

# %% [markdown]
# ### Step 1 - Convolution

# %%
classifier.add(Convolution2D(filters = 32, kernel_size = 3, input_shape = [64, 64, 3], activation = 'relu' ))

# %% [markdown]
# ### Step 2 - Pooling

# %%
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# %% [markdown]
# ### Adding a second convolutional layer

# %%
classifier.add(Convolution2D(filters=32, kernel_size=3, activation="relu"))
classifier.add(MaxPooling2D(pool_size=2))

# %% [markdown]
# ### Step 3 - Flattening

# %%
classifier.add(Flatten())

# %% [markdown]
# ### Step 4 - Full Connection

# %%
#adding the hidden layer
classifier.add(Dense(units = 128, activation = 'relu'))

# %% [markdown]
# ### Step 5 - Output Layer

# %%
classifier.add(Dense(units = 1, activation = 'sigmoid'))

# %% [markdown]
# ## Part 3 - Training the CNN

# %% [markdown]
# ### Compiling the CNN

# %%
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ### Training the CNN on the Training set and evaluating it on the Test set

# %%
#steps_per_epoch = TotalTrainingSamples / TrainingBatchSize
#validation_steps = TotalvalidationSamples / ValidationBatchSize
classifier.fit_generator(training_set,
                  steps_per_epoch = 250,
                  epochs = 25,
                  validation_data = test_set,
                  validation_steps = 63)
# Out:
# Epoch 1/25
# 250/250 [==============================] - 964s 4s/step - loss: 0.6718 - accuracy: 0.5859 - val_loss: 0.7158 - val_accuracy: 0.6785
# Epoch 2/25
# 250/250 [==============================] - 79s 317ms/step - loss: 0.6013 - accuracy: 0.6808 - val_loss: 0.6172 - val_accuracy: 0.7160
# Epoch 3/25
# 250/250 [==============================] - 79s 318ms/step - loss: 0.5684 - accuracy: 0.7016 - val_loss: 0.5747 - val_accuracy: 0.6995
# Epoch 4/25
# 250/250 [==============================] - 79s 314ms/step - loss: 0.5367 - accuracy: 0.7266 - val_loss: 0.5316 - val_accuracy: 0.7035
# Epoch 5/25
# 250/250 [==============================] - 79s 316ms/step - loss: 0.5208 - accuracy: 0.7401 - val_loss: 0.3306 - val_accuracy: 0.7185
# Epoch 6/25
# 250/250 [==============================] - 78s 314ms/step - loss: 0.4983 - accuracy: 0.7555 - val_loss: 0.3760 - val_accuracy: 0.7655
# Epoch 7/25
# ...
