# %% [markdown]
# # Artificial Neural Network

# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Importing the dataset

# %%
dataset = pd.read_csv('Churn_Modelling.csv')
X = dataset.iloc[:,3:-1].values
y = dataset.iloc[:,-1].values

# %%
print(X)
# Out:
# [[619 'France' 'Female' ... 1 1 101348.88]
#  [608 'Spain' 'Female' ... 0 1 112542.58]
#  [502 'France' 'Female' ... 1 0 113931.57]
#  ...
#  [709 'France' 'Female' ... 0 1 42085.58]
#  [772 'Germany' 'Male' ... 1 0 92888.52]
#  [792 'France' 'Female' ... 1 0 38190.78]]

# %%
print(y)
# Out:
# [1 0 1 ... 1 1 0]

# %% [markdown]
# ### Encoding categorical data

# %% [markdown]
# Label Encoding the "Gender" column

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
le = LabelEncoder()
X[:, 2] = le.fit_transform(X[:, 2])

# %%
print(X)
# Out:
# [[619 'France' 0 ... 1 1 101348.88]
#  [608 'Spain' 0 ... 0 1 112542.58]
#  [502 'France' 0 ... 1 0 113931.57]
#  ...
#  [709 'France' 0 ... 0 1 42085.58]
#  [772 'Germany' 1 ... 1 0 92888.52]
#  [792 'France' 0 ... 1 0 38190.78]]

# %% [markdown]
# One Hot Encoding the "Geography" column

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [1])],remainder='passthrough')
X = np.array(ct.fit_transform(X))

# %%
print(X)
# Out:
# [[1.0 0.0 0.0 ... 1 1 101348.88]
#  [0.0 0.0 1.0 ... 0 1 112542.58]
#  [1.0 0.0 0.0 ... 1 0 113931.57]
#  ...
#  [1.0 0.0 0.0 ... 0 1 42085.58]
#  [0.0 1.0 0.0 ... 1 0 92888.52]
#  [1.0 0.0 0.0 ... 1 0 38190.78]]

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)

# %%
print(X)
# Out:
# [[ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167  0.97024255
#    0.02188649]
#  [-1.00280393 -0.57873591  1.74273971 ... -1.54776799  0.97024255
#    0.21653375]
#  [ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167 -1.03067011
#    0.2406869 ]
#  ...
#  [ 0.99720391 -0.57873591 -0.57380915 ... -1.54776799  0.97024255
#   -1.00864308]
#  [-1.00280393  1.72790383 -0.57380915 ...  0.64609167 -1.03067011
#   -0.12523071]
#  [ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167 -1.03067011
#   -1.07636976]]

# %% [markdown]
# ### Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
print(len(X_train), len(X_test), len(y_train), len(y_test))
# Out:
# 8000 2000 8000 2000

# %% [markdown]
# ## Part 2 - Building the ANN

# %% [markdown]
# ### Importing packages

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# ### Initializing the ANN

# %%
classifier = Sequential()

# %% [markdown]
# ### Adding the input layer and the first hidden layer

# %%
classifier.add(Dense(units =6, activation = 'relu'))

# %% [markdown]
# ### Adding the second hidden layer

# %%
classifier.add(Dense(units =6, activation = 'relu'))

# %% [markdown]
# ### Adding the output layer

# %%
classifier.add(Dense(units =1, activation = 'sigmoid'))

# %% [markdown]
# ## Part 3 - Training the ANN

# %% [markdown]
# ### Compiling the ANN

# %%
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'] )

# %% [markdown]
# ### Training the ANN on the Training set

# %%
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 8000/8000 [==============================] - 1s 152us/step - loss: 0.5184 - accuracy: 0.7778
# Epoch 2/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.4329 - accuracy: 0.8112
# Epoch 3/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.4118 - accuracy: 0.8199
# Epoch 4/100
# 8000/8000 [==============================] - 1s 98us/step - loss: 0.3958 - accuracy: 0.8310
# Epoch 5/100
# 8000/8000 [==============================] - 1s 99us/step - loss: 0.3782 - accuracy: 0.8391
# Epoch 6/100
# 8000/8000 [==============================] - 1s 99us/step - loss: 0.3621 - accuracy: 0.8521
# Epoch 7/100
# 8000/8000 [==============================] - 1s 97us/step - loss: 0.3538 - accuracy: 0.8559
# Epoch 8/100
# 8000/8000 [==============================] - 1s 98us/step - loss: 0.3487 - accuracy: 0.8586
# Epoch 9/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3452 - accuracy: 0.8593
# Epoch 10/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3429 - accuracy: 0.8595
# Epoch 11/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3417 - accuracy: 0.8615
# Epoch 12/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3414 - accuracy: 0.8602
# Epoch 13/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.3411 - accuracy: 0.8621
# Epoch 14/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3402 - accuracy: 0.8606
# Epoch 15/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3397 - accuracy: 0.8615
# Epoch 16/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.3391 - accuracy: 0.8610
# Epoch 17/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3386 - accuracy: 0.8614
# Epoch 18/100
# 8000/8000 [==============================] - 1s 99us/step - loss: 0.3379 - accuracy: 0.8626
# Epoch 19/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3380 - accuracy: 0.8612
# Epoch 20/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3379 - accuracy: 0.8626
# Epoch 21/100
# 8000/8000 [==============================] - 1s 99us/step - loss: 0.3374 - accuracy: 0.8610
# Epoch 22/100
# 8000/8000 [==============================] - 1s 99us/step - loss: 0.3371 - accuracy: 0.8627
# Epoch 23/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3366 - accuracy: 0.8627
# Epoch 24/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3357 - accuracy: 0.8631
# Epoch 25/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3360 - accuracy: 0.8627
# Epoch 26/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3361 - accuracy: 0.8620
# Epoch 27/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3353 - accuracy: 0.8625
# Epoch 28/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3353 - accuracy: 0.8635
# Epoch 29/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3350 - accuracy: 0.8615
# Epoch 30/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3348 - accuracy: 0.8626
# Epoch 31/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3348 - accuracy: 0.8630
# Epoch 32/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3340 - accuracy: 0.8639
# Epoch 33/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3343 - accuracy: 0.8620
# Epoch 34/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3348 - accuracy: 0.8625
# Epoch 35/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3336 - accuracy: 0.8619
# Epoch 36/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3334 - accuracy: 0.8637
# Epoch 37/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3333 - accuracy: 0.8646
# Epoch 38/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3333 - accuracy: 0.8644
# Epoch 39/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3329 - accuracy: 0.8637
# Epoch 40/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3330 - accuracy: 0.8611
# Epoch 41/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3326 - accuracy: 0.8621
# Epoch 42/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3319 - accuracy: 0.8649
# Epoch 43/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3321 - accuracy: 0.8626
# Epoch 44/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3323 - accuracy: 0.8622
# Epoch 45/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3314 - accuracy: 0.8655
# Epoch 46/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3324 - accuracy: 0.8627
# Epoch 47/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3321 - accuracy: 0.8626
# Epoch 48/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3316 - accuracy: 0.8648
# Epoch 49/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3313 - accuracy: 0.8631
# Epoch 50/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.3316 - accuracy: 0.8643
# Epoch 51/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3318 - accuracy: 0.8624
# Epoch 52/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.3319 - accuracy: 0.8635
# Epoch 53/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3311 - accuracy: 0.8646
# Epoch 54/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.3320 - accuracy: 0.8639
# Epoch 55/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3312 - accuracy: 0.8671
# Epoch 56/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.3314 - accuracy: 0.8643
# Epoch 57/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3310 - accuracy: 0.8634
# Epoch 58/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3314 - accuracy: 0.8646
# Epoch 59/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3313 - accuracy: 0.8645
# Epoch 60/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3307 - accuracy: 0.8650
# Epoch 61/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3315 - accuracy: 0.8651
# Epoch 62/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.3312 - accuracy: 0.8636
# Epoch 63/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3316 - accuracy: 0.8634
# Epoch 64/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3308 - accuracy: 0.8640
# Epoch 65/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3308 - accuracy: 0.8637
# Epoch 66/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3308 - accuracy: 0.8649
# Epoch 67/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3309 - accuracy: 0.8644
# Epoch 68/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3309 - accuracy: 0.8645
# Epoch 69/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3306 - accuracy: 0.8649
# Epoch 70/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3308 - accuracy: 0.8641
# Epoch 71/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.3315 - accuracy: 0.8637
# Epoch 72/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3310 - accuracy: 0.8633
# Epoch 73/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3309 - accuracy: 0.8646
# Epoch 74/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3311 - accuracy: 0.8631
# Epoch 75/100
# 8000/8000 [==============================] - 1s 105us/step - loss: 0.3307 - accuracy: 0.8649
# Epoch 76/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3305 - accuracy: 0.8636
# Epoch 77/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.3309 - accuracy: 0.8660
# Epoch 78/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3307 - accuracy: 0.8651
# Epoch 79/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.3307 - accuracy: 0.8648
# Epoch 80/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3316 - accuracy: 0.8644
# Epoch 81/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.3308 - accuracy: 0.8644
# Epoch 82/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3309 - accuracy: 0.8633
# Epoch 83/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.3307 - accuracy: 0.8640
# Epoch 84/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3312 - accuracy: 0.8635
# Epoch 85/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3308 - accuracy: 0.8645
# Epoch 86/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3308 - accuracy: 0.8650
# Epoch 87/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3305 - accuracy: 0.8631
# Epoch 88/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3302 - accuracy: 0.8654
# Epoch 89/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3303 - accuracy: 0.8631
# Epoch 90/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3306 - accuracy: 0.8630
# Epoch 91/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.3305 - accuracy: 0.8651
# Epoch 92/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.3301 - accuracy: 0.8627
# Epoch 93/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3302 - accuracy: 0.8645
# Epoch 94/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3303 - accuracy: 0.8631
# Epoch 95/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3305 - accuracy: 0.8631
# Epoch 96/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3302 - accuracy: 0.8633
# Epoch 97/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3297 - accuracy: 0.8636
# Epoch 98/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3303 - accuracy: 0.8636
# Epoch 99/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.3300 - accuracy: 0.8633
# Epoch 100/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3299 - accuracy: 0.8637

# %% [markdown]
# ## Part 4 - Making the predictions and evaluating the model

# %% [markdown]
# ### Predicting the Test set results

# %%
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5 )
print(y_pred)
# Out:
# [[False]
#  [False]
#  [False]
#  ...
#  [False]
#  [False]
#  [False]]

# %% [markdown]
# ### Making the Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[1502   93]
#  [ 197  208]]
